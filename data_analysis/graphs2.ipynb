# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].unique()) #categorical columns
print(titanic['pclass'].unique())
print(titanic['sex'].unique())
# Out:
# [0 1]
# [3 1 2]
# ['male' 'female']

# %% [markdown]
# # Categorical graphs
#  - columns that have text are generally categorical
#  - the first step is to count the number of unique values in column
#  - then plot the count of each category
#  - folowing charts are a good way to visualize categorcal data
#     - bar chart -
#     - pie chart
#     - donut chart
#     - line chart - when too many categories
#     - area chart - when too many categories

# %%
survival_count = titanic['survived'].value_counts()
survival_count.plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
survival_count = titanic['survived'].value_counts()
survival_count.plot(kind = 'pie', autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
survival_count = titanic['alive'].value_counts()
survival_count.plot(kind = 'pie', autopct='%.1f%%',title='Survival rate')
# Out:
# <Axes: title={'center': 'Survival rate'}, ylabel='count'>

# %%
p_class = titanic['pclass'].value_counts()
p_class.plot(kind = 'pie', autopct='%.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
survival_count.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'Survival Rate',
    labels = ['Survived','Not Survived'],
    colors = ['#66b3ff','#ff9999'],
    labeldistance=1.1,
    wedgeprops={
        'width' : 0.5,
    })
# Out:
# <Axes: title={'center': 'Survival Rate'}, ylabel='count'>

# %%
p_class = titanic['pclass'].value_counts()
p_class
# Out:
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
p_class.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'Number of peolpe in different levels of ships',
    labels = ['3','1','2'],
    colors = ['#66b3ff','#ff9999','#ffbb11'],
    labeldistance=1.1,
    wedgeprops={
        'width' : 0.5,
    })
# Out:
# <Axes: title={'center': 'Number of peolpe in different levels of ships'}, ylabel='count'>

# %% [markdown]
# # Seaborn
# - for complete data visualization using simple code

# %%
sns.countplot(data = titanic,x ='alive')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data = titanic,x ='alive', hue='sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data = titanic,x ='alive', hue='sex')
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(data = titanic,x ='pclass', hue='alive')
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data = titanic,y ='pclass', hue='embark_town') #hue grouping the data
# Out:
# <Axes: xlabel='count', ylabel='pclass'>

# %%
sns.countplot?
# Out:
# Signature:
# sns.countplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     width=0.8,
#     dodge=True,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead
# of quantitative, variable. The basic API and options are identical to those
# for :func:`barplot`, so you can compare counts across nested variables.
#
# Note that the newer :func:`histplot` function offers more functionality, although
# its default behavior is somewhat different.
#
# .. note::
#     This function always treats one of the variables as categorical and
#     draws data at ordinal positions (0, 1, ... n) on the relevant axis,
#     even when the data has a numeric or date type.
#
# ...

# %%
sns.jointplot? #numerical columns
# Out:
# Signature:
# sns.jointplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     kind='scatter',
#     height=6,
#     ratio=5,
#     space=0.2,
#     dropna=False,
#     xlim=None,
#     ylim=None,
#     color=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     marginal_ticks=False,
#     joint_kws=None,
#     marginal_kws=None,
#     **kwargs,
# )
# Docstring:
# Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.
#
# Parameters
# ----------
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be
# ...

# %%
sns.jointplot(data =titanic,x='fare',y='age')

# %%
sns.jointplot(data =titanic,x='fare',y='age',kind='hex')

# %%
sns.jointplot(data =titanic,x='fare',y='age',kind='scatter',hue='survived')
