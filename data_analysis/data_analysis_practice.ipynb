# %%
import pandas as pd
import numpy as np

# %%
file ='gender_development.csv'
dev= pd.read_csv(file,skipfooter=1)
dev
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_21072\2681177734.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dev= pd.read_csv(file,skipfooter=1)
#      GDI Rank                          Country Gender Development Index (GDI)  \
# 0         1.0                           Norway                          0.996
# 1         2.0                        Australia                          0.976
# 2         3.0                      Switzerland                           0.95
# 3         4.0                          Denmark                          0.977
# 4         5.0                      Netherlands                          0.947
# ..        ...                              ...                            ...
# 189       NaN        East Asia and the Pacific                          0.948
# 190       NaN          Europe and Central Asia                          0.945
# ...

# %%
dev
# Out:
#      GDI Rank                          Country Gender Development Index (GDI)  \
# 0         1.0                           Norway                          0.996
# 1         2.0                        Australia                          0.976
# 2         3.0                      Switzerland                           0.95
# 3         4.0                          Denmark                          0.977
# 4         5.0                      Netherlands                          0.947
# ..        ...                              ...                            ...
# 189       NaN        East Asia and the Pacific                          0.948
# 190       NaN          Europe and Central Asia                          0.945
# 191       NaN  Latin America and the Caribbean                          0.976
# 192       NaN                       South Asia                          0.801
# 193       NaN               Sub-Saharan Africa                          0.872
#
# ...

# %%
dev['Country']
# Out:
# 0                               Norway
# 1                            Australia
# 2                          Switzerland
# 3                              Denmark
# 4                          Netherlands
#                     ...
# 189          East Asia and the Pacific
# 190            Europe and Central Asia
# 191    Latin America and the Caribbean
# 192                         South Asia
# 193                 Sub-Saharan Africa
# Name: Country, Length: 194, dtype: object

# %%
dev.head()
# Out:
#    GDI Rank      Country Gender Development Index (GDI)  \
# 0       1.0       Norway                          0.996
# 1       2.0    Australia                          0.976
# 2       3.0  Switzerland                           0.95
# 3       4.0      Denmark                          0.977
# 4       5.0  Netherlands                          0.947
#
#   Human Development Index (Female) Human Development Index (Male)  \
# 0                             0.94                          0.944
# 1                            0.922                          0.945
# 2                            0.898                          0.945
# 3                            0.912                          0.934
# 4                            0.893                          0.943
#
#   Life Expectancy at Birth (Female) Life Expectancy at Birth (Male)  \
# 0                              83.6                            79.5
# 1                              84.5                            80.3
# ...

# %%
dev.head(10)
# Out:
#    GDI Rank        Country Gender Development Index (GDI)  \
# 0       1.0         Norway                          0.996
# 1       2.0      Australia                          0.976
# 2       3.0    Switzerland                           0.95
# 3       4.0        Denmark                          0.977
# 4       5.0    Netherlands                          0.947
# 5       6.0        Germany                          0.963
# 6       6.0        Ireland                          0.973
# 7       8.0  United States                          0.995
# 8       9.0         Canada                          0.982
# 9       9.0    New Zealand                          0.961
#
#   Human Development Index (Female) Human Development Index (Male)  \
# 0                             0.94                          0.944
# 1                            0.922                          0.945
# 2                            0.898                          0.945
# ...

# %%
dev.tail()
# Out:
#      GDI Rank                          Country Gender Development Index (GDI)  \
# 189       NaN        East Asia and the Pacific                          0.948
# 190       NaN          Europe and Central Asia                          0.945
# 191       NaN  Latin America and the Caribbean                          0.976
# 192       NaN                       South Asia                          0.801
# 193       NaN               Sub-Saharan Africa                          0.872
#
#     Human Development Index (Female) Human Development Index (Male)  \
# 189                            0.692                           0.73
# 190                            0.719                           0.76
# 191                            0.736                          0.754
# 192                            0.525                          0.655
# 193                             0.48                           0.55
#
#     Life Expectancy at Birth (Female) Life Expectancy at Birth (Male)  \
# ...

# %%
dev.tail(15)
# Out:
#      GDI Rank                          Country Gender Development Index (GDI)  \
# 179     180.0                       Mozambique                          0.881
# 180     181.0                     Sierra Leone                          0.814
# 181     182.0                           Guinea                          0.778
# 182     183.0                     Burkina Faso                          0.881
# 183     184.0                          Burundi                          0.911
# 184     185.0                             Chad                          0.768
# 185     186.0                          Eritrea                             ..
# 186     187.0         Central African Republic                          0.773
# 187     188.0                            Niger                          0.729
# 188       NaN                      Arab States                          0.849
# 189       NaN        East Asia and the Pacific                          0.948
# ...

# %%
dev.sample(10)
# Out:
#      GDI Rank                             Country  \
# 88       89.0                         Saint Lucia
# 27       28.0                      Czech Republic
# 101     101.0                  Dominican Republic
# 4         5.0                         Netherlands
# 79       80.0                              Jordan
# 76       77.0               Saint Kitts and Nevis
# 166     167.0                               Sudan
# 46       47.0                             Croatia
# 148     149.0                              Angola
# 175     176.0  Congo (Democratic Republic of the)
#
#     Gender Development Index (GDI) Human Development Index (Female)  \
# 88                           0.991                            0.725
# 27                            0.98                            0.859
# 101                          0.995                             0.71
# 4                            0.947                            0.893
# 79                            0.86                            0.674
# ...

# %%
dev[15:31]
# Out:
#     GDI Rank              Country Gender Development Index (GDI)  \
# 15      16.0              Iceland                          0.975
# 16      17.0  Korea (Republic of)                           0.93
# 17      18.0               Israel                          0.971
# 18      19.0           Luxembourg                          0.971
# 19      20.0                Japan                          0.961
# 20      21.0              Belgium                          0.975
# 21      22.0               France                          0.987
# 22      23.0              Austria                          0.943
# 23      24.0              Finland                          0.996
# 24      25.0             Slovenia                          0.996
# 25      26.0                Spain                          0.975
# 26      27.0                Italy                          0.964
# 27      28.0       Czech Republic                           0.98
# ...

# %%
dev['Country']
# Out:
# 0                               Norway
# 1                            Australia
# 2                          Switzerland
# 3                              Denmark
# 4                          Netherlands
#                     ...
# 189          East Asia and the Pacific
# 190            Europe and Central Asia
# 191    Latin America and the Caribbean
# 192                         South Asia
# 193                 Sub-Saharan Africa
# Name: Country, Length: 194, dtype: object

# %%
dev.Country
# Out:
# 0                               Norway
# 1                            Australia
# 2                          Switzerland
# 3                              Denmark
# 4                          Netherlands
#                     ...
# 189          East Asia and the Pacific
# 190            Europe and Central Asia
# 191    Latin America and the Caribbean
# 192                         South Asia
# 193                 Sub-Saharan Africa
# Name: Country, Length: 194, dtype: object

# %%
dev[['Country','GDI Rank']]
# Out:
#                              Country  GDI Rank
# 0                             Norway       1.0
# 1                          Australia       2.0
# 2                        Switzerland       3.0
# 3                            Denmark       4.0
# 4                        Netherlands       5.0
# ..                               ...       ...
# 189        East Asia and the Pacific       NaN
# 190          Europe and Central Asia       NaN
# 191  Latin America and the Caribbean       NaN
# 192                       South Asia       NaN
# 193               Sub-Saharan Africa       NaN
#
# [194 rows x 2 columns]

# %%
dev.set_index('Country',inplace=True)

# %%
dev
# Out:
#                                  GDI Rank Gender Development Index (GDI)  \
# Country
# Norway                                1.0                          0.996
# Australia                             2.0                          0.976
# Switzerland                           3.0                           0.95
# Denmark                               4.0                          0.977
# Netherlands                           5.0                          0.947
# ...                                   ...                            ...
# East Asia and the Pacific             NaN                          0.948
# Europe and Central Asia               NaN                          0.945
# Latin America and the Caribbean       NaN                          0.976
# South Asia                            NaN                          0.801
# Sub-Saharan Africa                    NaN                          0.872
#
#                                 Human Development Index (Female)  \
# Country
# ...

# %%
dev.iloc[0]
# Out:
# GDI Rank                                                 1.0
# Gender Development Index (GDI)                         0.996
# Human Development Index (Female)                        0.94
# Human Development Index (Male)                         0.944
# Life Expectancy at Birth (Female)                       83.6
# Life Expectancy at Birth (Male)                         79.5
# Expected Years of Education (Female)                    18.2
# Expected Years of Education (Male)                      16.8
# Mean Years of Education (Female)                        12.7
# Mean Years of Education (Male)                          12.5
# Estimated Gross National Income per Capita (Female)    57140
# Estimated Gross National Income per Capita (Male)      72825
# Name: Norway, dtype: object

# %%
dev.iloc[10:30]
# Out:
#                         GDI Rank Gender Development Index (GDI)  \
# Country
# Singapore                   11.0                          0.985
# Hong Kong, China (SAR)      12.0                          0.958
# Liechtenstein               13.0                             ..
# Sweden                      14.0                          0.999
# United Kingdom              14.0                          0.965
# Iceland                     16.0                          0.975
# Korea (Republic of)         17.0                           0.93
# Israel                      18.0                          0.971
# Luxembourg                  19.0                          0.971
# Japan                       20.0                          0.961
# Belgium                     21.0                          0.975
# France                      22.0                          0.987
# Austria                     23.0                          0.943
# ...

# %%
dev.iloc[10:16, :6]
# Out:
#                         GDI Rank Gender Development Index (GDI)  \
# Country
# Singapore                   11.0                          0.985
# Hong Kong, China (SAR)      12.0                          0.958
# Liechtenstein               13.0                             ..
# Sweden                      14.0                          0.999
# United Kingdom              14.0                          0.965
# Iceland                     16.0                          0.975
#
#                        Human Development Index (Female)  \
# Country
# Singapore                                         0.898
# Hong Kong, China (SAR)                            0.892
# Liechtenstein                                        ..
# Sweden                                            0.906
# United Kingdom                                    0.888
# Iceland                                           0.886
#
#                        Human Development Index (Male)  \
# Country
# ...

# %%
dev.loc['Norway']
# Out:
# GDI Rank                                                 1.0
# Gender Development Index (GDI)                         0.996
# Human Development Index (Female)                        0.94
# Human Development Index (Male)                         0.944
# Life Expectancy at Birth (Female)                       83.6
# Life Expectancy at Birth (Male)                         79.5
# Expected Years of Education (Female)                    18.2
# Expected Years of Education (Male)                      16.8
# Mean Years of Education (Female)                        12.7
# Mean Years of Education (Male)                          12.5
# Estimated Gross National Income per Capita (Female)    57140
# Estimated Gross National Income per Capita (Male)      72825
# Name: Norway, dtype: object

# %%
vs= dev.loc[['Japan','Singapore']]

# %%
vs
# Out:
#            GDI Rank Gender Development Index (GDI)  \
# Country
# Japan          20.0                          0.961
# Singapore      11.0                          0.985
#
#           Human Development Index (Female) Human Development Index (Male)  \
# Country
# Japan                                 0.87                          0.905
# Singapore                            0.898                          0.912
#
#           Life Expectancy at Birth (Female) Life Expectancy at Birth (Male)  \
# Country
# Japan                                  86.7                            80.2
# Singapore                                86                            79.9
#
#           Expected Years of Education (Female)  \
# Country
# Japan                                     15.2
# Singapore                                 15.5
#
#           Expected Years of Education (Male) Mean Years of Education (Female)  \
# Country
# ...

# %%
vs.plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
dev.shape
# Out:
# (194, 12)

# %%
vs.T
# Out:
# Country                                             Japan Singapore
# GDI Rank                                             20.0      11.0
# Gender Development Index (GDI)                      0.961     0.985
# Human Development Index (Female)                     0.87     0.898
# Human Development Index (Male)                      0.905     0.912
# Life Expectancy at Birth (Female)                    86.7        86
# Life Expectancy at Birth (Male)                      80.2      79.9
# Expected Years of Education (Female)                 15.2      15.5
# Expected Years of Education (Male)                   15.5      15.3
# Mean Years of Education (Female)                     11.3      10.1
# Mean Years of Education (Male)                       11.7      10.9
# Estimated Gross National Income per Capita (Fem...  24975     59994
# Estimated Gross National Income per Capita (Male)   49541     93699
